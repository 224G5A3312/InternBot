# %%
# !pip install transformers torch accelerate
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting transformers
#   Downloading transformers-4.56.1-py3-none-any.whl.metadata (42 kB)
# Collecting torch
#   Using cached torch-2.8.0-cp313-cp313-win_amd64.whl.metadata (30 kB)
# Collecting accelerate
#   Downloading accelerate-1.10.1-py3-none-any.whl.metadata (19 kB)
# Collecting filelock (from transformers)
#   Using cached filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers)
#   Using cached huggingface_hub-0.34.4-py3-none-any.whl.metadata (14 kB)
# Collecting numpy>=1.17 (from transformers)
#   Using cached numpy-2.3.3-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from transformers) (6.0.2)
# Collecting regex!=2019.12.17 (from transformers)
#   Using cached regex-2025.9.1-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: requests in c:\users\hp\appdata\roaming\python\python313\site-packages (from transformers) (2.32.5)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Using cached tokenizers-0.22.0-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.6.2-cp38-abi3-win_amd64.whl.metadata (4.1 kB)
# Collecting tqdm>=4.27 (from transformers)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.34.0->transformers)
#   Using cached fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\hp\appdata\roaming\python\python313\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Using cached networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in c:\users\hp\appdata\roaming\python\python313\site-packages (from torch) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\hp\appdata\roaming\python\python313\site-packages (from torch) (80.9.0)
# Requirement already satisfied: psutil in c:\users\hp\appdata\roaming\python\python313\site-packages (from accelerate) (7.0.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: colorama in c:\users\hp\appdata\roaming\python\python313\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\appdata\roaming\python\python313\site-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\roaming\python\python313\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\appdata\roaming\python\python313\site-packages (from requests->transformers) (2025.8.3)
# Downloading transformers-4.56.1-py3-none-any.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.6 MB 1.4 MB/s eta 0:00:08
#    --- ------------------------------------ 1.0/11.6 MB 1.5 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.3/11.6 MB 1.4 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.6/11.6 MB 1.4 MB/s eta 0:00:07
#    ------ --------------------------------- 1.8/11.6 MB 1.4 MB/s eta 0:00:07
#    ------- -------------------------------- 2.1/11.6 MB 1.4 MB/s eta 0:00:07
#    -------- ------------------------------- 2.4/11.6 MB 1.4 MB/s eta 0:00:07
#    --------- ------------------------------ 2.6/11.6 MB 1.4 MB/s eta 0:00:07
#    ---------- ----------------------------- 3.1/11.6 MB 1.4 MB/s eta 0:00:06
#    ----------- ---------------------------- 3.4/11.6 MB 1.4 MB/s eta 0:00:06
#    ------------ --------------------------- 3.7/11.6 MB 1.4 MB/s eta 0:00:06
#    ------------- -------------------------- 3.9/11.6 MB 1.4 MB/s eta 0:00:06
#    -------------- ------------------------- 4.2/11.6 MB 1.4 MB/s eta 0:00:06
#    --------------- ------------------------ 4.5/11.6 MB 1.4 MB/s eta 0:00:06
#    ---------------- ----------------------- 4.7/11.6 MB 1.4 MB/s eta 0:00:05
#    ----------------- ---------------------- 5.0/11.6 MB 1.4 MB/s eta 0:00:05
#    ------------------ --------------------- 5.2/11.6 MB 1.4 MB/s eta 0:00:05
#    ------------------- -------------------- 5.8/11.6 MB 1.4 MB/s eta 0:00:05
#    -------------------- ------------------- 6.0/11.6 MB 1.4 MB/s eta 0:00:05
#    --------------------- ------------------ 6.3/11.6 MB 1.4 MB/s eta 0:00:04
#    ---------------------- ----------------- 6.6/11.6 MB 1.4 MB/s eta 0:00:04
#    ----------------------- ---------------- 6.8/11.6 MB 1.4 MB/s eta 0:00:04
#    ------------------------ --------------- 7.1/11.6 MB 1.4 MB/s eta 0:00:04
#    ------------------------- -------------- 7.3/11.6 MB 1.4 MB/s eta 0:00:04
#    -------------------------- ------------- 7.6/11.6 MB 1.4 MB/s eta 0:00:03
#    --------------------------- ------------ 7.9/11.6 MB 1.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 8.1/11.6 MB 1.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 8.4/11.6 MB 1.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 8.7/11.6 MB 1.3 MB/s eta 0:00:03
#    ------------------------------ --------- 8.9/11.6 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 9.4/11.6 MB 1.4 MB/s eta 0:00:02
#    --------------------------------- ------ 9.7/11.6 MB 1.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.0/11.6 MB 1.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 10.2/11.6 MB 1.4 MB/s eta 0:00:02
#    ------------------------------------ --- 10.5/11.6 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 11.0/11.6 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 11.3/11.6 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.6 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 1.4 MB/s eta 0:00:00
# Using cached huggingface_hub-0.34.4-py3-none-any.whl (561 kB)
# Using cached tokenizers-0.22.0-cp39-abi3-win_amd64.whl (2.7 MB)
# Using cached torch-2.8.0-cp313-cp313-win_amd64.whl (241.3 MB)
# Downloading accelerate-1.10.1-py3-none-any.whl (374 kB)
# Using cached numpy-2.3.3-cp313-cp313-win_amd64.whl (12.8 MB)
# Using cached fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Using cached regex-2025.9.1-cp313-cp313-win_amd64.whl (275 kB)
# Using cached safetensors-0.6.2-cp38-abi3-win_amd64.whl (320 kB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached filelock-3.19.1-py3-none-any.whl (15 kB)
# Using cached networkx-3.5-py3-none-any.whl (2.0 MB)
# Installing collected packages: mpmath, tqdm, sympy, safetensors, regex, numpy, networkx, fsspec, filelock, torch, huggingface-hub, tokenizers, accelerate, transformers
#
#    ----------------------------------------  0/14 [mpmath]
#    ----------------------------------------  0/14 [mpmath]
#    ----------------------------------------  0/14 [mpmath]
#    ----------------------------------------  0/14 [mpmath]
#    ----------------------------------------  0/14 [mpmath]
#    ----------------------------------------  0/14 [mpmath]
#    ----------------------------------------  0/14 [mpmath]
#    ----------------------------------------  0/14 [mpmath]
#    ----------------------------------------  0/14 [mpmath]
#    ----------------------------------------  0/14 [mpmath]
#    ----------------------------------------  0/14 [mpmath]
#    ----------------------------------------  0/14 [mpmath]
#    ----------------------------------------  0/14 [mpmath]
#    ----------------------------------------  0/14 [mpmath]
#    ----------------------------------------  0/14 [mpmath]
#    ----------------------------------------  0/14 [mpmath]
#    -- -------------------------------------  1/14 [tqdm]
#    -- -------------------------------------  1/14 [tqdm]
#    -- -------------------------------------  1/14 [tqdm]
#    -- -------------------------------------  1/14 [tqdm]
#    -- -------------------------------------  1/14 [tqdm]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----------- ----------------------------  4/14 [regex]
#    ----------- ----------------------------  4/14 [regex]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    -------------- -------------------------  5/14 [numpy]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    -------------------- -------------------  7/14 [fsspec]
#    -------------------- -------------------  7/14 [fsspec]
#    -------------------- -------------------  7/14 [fsspec]
#    -------------------- -------------------  7/14 [fsspec]
#    -------------------- -------------------  7/14 [fsspec]
#    -------------------- -------------------  7/14 [fsspec]
#    -------------------- -------------------  7/14 [fsspec]
#    -------------------- -------------------  7/14 [fsspec]
#    -------------------- -------------------  7/14 [fsspec]
#    ---------------------- -----------------  8/14 [filelock]
#    ---------------------- -----------------  8/14 [filelock]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
# ...
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ------------------------------------- -- 13/14 [transformers]
#    ---------------------------------------- 14/14 [transformers]
#
# Successfully installed accelerate-1.10.1 filelock-3.19.1 fsspec-2025.9.0 huggingface-hub-0.34.4 mpmath-1.3.0 networkx-3.5 numpy-2.3.3 regex-2025.9.1 safetensors-0.6.2 sympy-1.14.0 tokenizers-0.22.0 torch-2.8.0 tqdm-4.67.1 transformers-4.56.1
#   WARNING: The script tqdm.exe is installed in 'C:\Users\HP\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script isympy.exe is installed in 'C:\Users\HP\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\HP\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts torchfrtrace.exe and torchrun.exe are installed in 'C:\Users\HP\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts hf.exe, huggingface-cli.exe and tiny-agents.exe are installed in 'C:\Users\HP\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts accelerate-config.exe, accelerate-estimate-memory.exe, accelerate-launch.exe, accelerate-merge-weights.exe and accelerate.exe are installed in 'C:\Users\HP\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts transformers-cli.exe and transformers.exe are installed in 'C:\Users\HP\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from transformers import pipeline

# ✅ Load Hugging Face model
generator = pipeline("text-generation", model="tiiuae/falcon-7b-instruct", device_map="auto")

def generate_interview_questions(job_role):
    # Predefined technical questions for each role
    role_questions = {
        "software engineer": [
            "Explain the concept of time complexity and give an example.",
            "What are the differences between processes and threads?",
            "How does garbage collection work in Java or Python?",
            "Can you explain object-oriented programming principles?",
            "What is the purpose of databases indexes?"
        ],
        "ai engineer": [
            "What is the difference between supervised and unsupervised learning?",
            "Explain the architecture of a neural network.",
            "How do you prevent overfitting in machine learning models?",
            "What is gradient descent and why is it important?",
            "Describe how transformers work in NLP."
        ],
        "data analyst": [
            "What are the differences between OLTP and OLAP systems?",
            "Explain how you would handle missing data in a dataset.",
            "What is the difference between inner join and outer join in SQL?",
            "How would you explain p-value to a non-technical person?",
            "What visualization would you use to compare distributions of two datasets?"
        ],
        "front end developer": [
            "What is the difference between React, Angular, and Vue?",
            "Explain how the virtual DOM works in React.",
            "What are CSS Flexbox and Grid, and when would you use them?",
            "How does JavaScript handle asynchronous code?",
            "Explain the concept of responsive design and how to achieve it."
        ]
    }

    job_role = job_role.lower()
    if job_role not in role_questions:
        return ["Invalid role. Please choose from: Software Engineer, AI Engineer, Data Analyst, Front End Developer."]

    return role_questions[job_role]

if __name__ == "__main__":
    role = input("Enter the Intern Job Role (Software Engineer, AI Engineer, Data Analyst, Front End Developer):\n> ")
    questions = generate_interview_questions(role)

    print("\nGenerated Technical Interview Questions:\n")
    for i, q in enumerate(questions, 1):
        print(f"{i}. {q}")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu and disk.
# Device set to use cuda:0
# Enter the Intern Job Role (Software Engineer, AI Engineer, Data Analyst, Front End Developer):
# > AI Engineer
#
# Generated Technical Interview Questions:
#
# 1. What is the difference between supervised and unsupervised learning?
# 2. Explain the architecture of a neural network.
# 3. How do you prevent overfitting in machine learning models?
# 4. What is gradient descent and why is it important?
# 5. Describe how transformers work in NLP.
